# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
read = '/home/zoro/Desktop/datafest2018/DataFest-Dataset-2018.csv/output/'
write= '/home/zoro/Desktop/datafest2018/DataFest-Dataset-2018.csv/output/'
filename = 'new_US_companies.csv'

# %%
df = pd.read_csv(read+filename).drop(['Unnamed: 0'], axis=1) # read the file and drop first column

# %%
df.shape
# Out:
# (11547904, 12)

# %%
df.head()
# Out:
#          date     companyId       jobId stateProvince  \
# 0  2016-11-01  company00002  job0000002            AZ
# 1  2016-11-01  company00977  job0046801            FL
# 2  2016-11-01  company34117  job0070172            TX
# 3  2016-11-01  company05230  job0010362            NY
# 4  2016-11-01  company20349  job0054168            MI
#
#                              city     industry  \
# 0                          Peoria          NaN
# 1                     Gainesville  HEALTH_CARE
# 2                          Dallas          NaN
# 3                         Yonkers          NaN
# 4  Charter Township of Brownstown          NaN
#
#                          normTitle normTitleCategory  experienceRequired  \
# 0  customer service representative          customer                 NaN
# 1                     case manager           service                 NaN
# 2  licensed clinical social worker           service                 NaN
# ...

# %%
df[df.industry.notnull()].industrynew.unique()
# Out:
# array(['Healthcare', 'Manufacturing_and_Retail', 'Government',
#        'Technology', 'Financial Activities', 'Education',
#        'Transportation and Warehousing', 'Business', 'Hospitality',
#        'Utilities', 'construction/real_estate', 'Agriculture',
#        'Other Services'], dtype=object)

# %%
df1 = df[df.industrynew.notnull()]

# %%
list1 = df1[df1.industrynew == 'Healthcare']['normTitle'].unique()

# %%
df1.shape
# Out:
# (1384568, 12)

# %%
list1.shape
# Out:
# (1517,)

# %%
list1[0]
# Out:
# 'case manager'

# %%
industry_normtitle_salary = df1.groupby(["industrynew","normTitle"])["estimatedSalary"].mean()

# %%
df2=industry_normtitle_salary.to_frame()

# %%
df2.tail()
# Out:
#                                          estimatedSalary
# industrynew              normTitle
# construction/real_estate welder             38115.625000
#                          welder/fitter      41900.000000
#                          window cleaner     23400.000000
#                          works manager      86700.000000
#                          yard worker        22588.888889

# %%
df2.shape
# Out:
# (10104, 1)

# %%
df2 = df2.reset_index()

# %%
df2.shape
# Out:
# (10104, 3)

# %%
df2.columns
# Out:
# Index([u'industrynew', u'normTitle', u'estimatedSalary'], dtype='object')

# %%
df.shape
# Out:
# (11547904, 12)

# %%
df.normTitle.nunique()
# Out:
# 5099

# %%
total_normtitle_salary = df1.groupby(["normTitle"])["estimatedSalary"].mean()

# %%
tns=total_normtitle_salary.to_frame()

# %%
tns = tns.reset_index()

# %%
tns.shape
# Out:
# (3625, 2)

# %%
tns.head(100)
tns.columns = ['normTitle','estimatedSalarycompletedataset']

# %%
tns.head()
# Out:
#                    normTitle  estimatedSalarycompletedataset
# 0             .net developer                    90117.260579
# 1  2nd line support engineer                    22000.000000
# 2     3d printing technician                    81900.000000
# 3                  a&e nurse                    52513.953488
# 4              aba therapist                    37619.565217

# %%
for index, row in tns.iterrows():
    print row[index]
    print row['estimatedSalary']
    break
# Out:
# .net developer
# 90117.2605791

# %%
df2['salary_from_dataset']=0
df2
# Out:
#                     industrynew                               normTitle  \
# 0                   Agriculture                         account manager
# 1                   Agriculture                  account representative
# 2                   Agriculture                      accounting manager
# 3                   Agriculture               accounts receivable clerk
# 4                   Agriculture                administrative assistant
# 5                   Agriculture              administrative coordinator
# 6                   Agriculture                           administrator
# 7                   Agriculture                     admission counselor
# 8                   Agriculture                        agronomy manager
# 9                   Agriculture                                 analyst
# 10                  Agriculture                     application analyst
# 11                  Agriculture                               assistant
# ...

# %%
df2 = df2.drop(['salary_from_dataset'],axis=1)

# %%
df2.head()
# Out:
#    industrynew                  normTitle  estimatedSalary
# 0  Agriculture            account manager     46882.142857
# 1  Agriculture     account representative     50000.000000
# 2  Agriculture         accounting manager     67300.000000
# 3  Agriculture  accounts receivable clerk     46000.000000
# 4  Agriculture   administrative assistant     25347.058824

# %%
df3 = pd.merge(tns,df2,on='normTitle')

# %%
df3.shape
# Out:
# (10104, 4)

# %%
df3.head(100)
# Out:
#                     normTitle  estimatedSalarycompletedataset  \
# 0              .net developer                    90117.260579
# 1              .net developer                    90117.260579
# 2              .net developer                    90117.260579
# 3              .net developer                    90117.260579
# 4              .net developer                    90117.260579
# 5              .net developer                    90117.260579
# 6              .net developer                    90117.260579
# 7   2nd line support engineer                    22000.000000
# 8      3d printing technician                    81900.000000
# 9                   a&e nurse                    52513.953488
# 10              aba therapist                    37619.565217
# 11           academic advisor                    36309.090909
# 12         academic counselor                    32542.253521
# 13             access manager                    48019.696970
# ...

# %%
df3.columns
# Out:
# Index([u'normTitle', u'estimatedSalarycompletedataset', u'industrynew',
#        u'estimatedSalary'],
#       dtype='object')

# %%
df3['thresh'] = df3['estimatedSalarycompletedataset']-df3['estimatedSalary']

# %%
df3.head(100)
# Out:
#                     normTitle  estimatedSalarycompletedataset  \
# 0              .net developer                    90117.260579
# 1              .net developer                    90117.260579
# 2              .net developer                    90117.260579
# 3              .net developer                    90117.260579
# 4              .net developer                    90117.260579
# 5              .net developer                    90117.260579
# 6              .net developer                    90117.260579
# 7   2nd line support engineer                    22000.000000
# 8      3d printing technician                    81900.000000
# 9                   a&e nurse                    52513.953488
# 10              aba therapist                    37619.565217
# 11           academic advisor                    36309.090909
# 12         academic counselor                    32542.253521
# 13             access manager                    48019.696970
# ...

# %%
df3.shape
# Out:
# (10104, 5)

# %%
dfnan = df[df.industrynew.isnull()]

# %%
dfnan.shape
# Out:
# (10163336, 12)

# %%
df1.shape
# Out:
# (1384568, 12)

# %%
dfnan['newestimatedSalary']=0
# Out:
# /home/zoro/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfnan.shape
# Out:
# (10163336, 13)

# %%
df1['newestimatedSalary']=df1['estimatedSalary']
# Out:
# /home/zoro/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.shape
# Out:
# (1384568, 13)

# %%
dfnan.to_csv(write+'nanCompanies.csv')
df1.to_csv(write+'filledCompanies.csv')
df3.to_csv(write+'lookuptable.csv')
