# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
read = '/Users/Apoorva.Rajesh.Joshi@ibm.com/Desktop/Ap version/months/'
#write= '/Users/Apoorva.Rajesh.Joshi@ibm.com/Desktop/Ap version/'
filename = 'nov16.csv'

# %%
cd /Users/Apoorva.Rajesh.Joshi@ibm.com/Desktop/Ap version/months
# Out:
# /Users/Apoorva.Rajesh.Joshi@ibm.com/Desktop/Ap version/months

# %%
pwd
# Out:
# '/Users/Apoorva.Rajesh.Joshi@ibm.com/Desktop/Ap version/months'

# %%
df = pd.read_csv(read+filename).drop(['Unnamed: 0'], axis=1)

# %%
df.shape
# Out:
# (788435, 24)

# %%
df['label'] = df.groupby(['companyId', 'jobId']).ngroup()

# %%
df.label.nunique()
# Out:
# 57303

# %%
df.companyId.nunique()
# Out:
# 25278

# %%
df.jobId.count()
# Out:
# 788435

# %%
df.companyId.count()
# Out:
# 788435

# %%
df.columns
# Out:
# Index(['date', 'companyId', 'jobId', 'country', 'stateProvince', 'city',
#        'avgOverallRating', 'numReviews', 'industry', 'normTitle',
#        'normTitleCategory', 'descriptionCharacterLength',
#        'descriptionWordCount', 'experienceRequired', 'estimatedSalary',
#        'salaryCurrency', 'jobLanguage', 'supervisingJob', 'licenseRequiredJob',
#        'educationRequirements', 'jobAgeDays', 'clicks', 'localClicks',
#        'label'],
#       dtype='object')

# %%
df.groupby('stateProvince')['companyId'].nunique().sort_values().to_csv(write+'companies_'+filename)  # no of unique companies per state per month

# %%
df.groupby('stateProvince')['jobId'].nunique().sort_values().to_csv(write+'jobs_'+filename)  # no of unique jobs per state per month

# %%
df.head(100)
# Out:
#           date     companyId       jobId country stateProvince  \
# 0   2016-11-01  company00002  job0000002      US            AZ
# 1   2016-11-01  company00977  job0046801      US            FL
# 2   2016-11-01  company34117  job0070172      US            TX
# 3   2016-11-01  company05230  job0010362      US            NY
# 4   2016-11-01  company20349  job0054168      US            MI
# 5   2016-11-01  company03785  job0024376      US            IA
# 6   2016-11-01  company27976  job0060502      US            NC
# 7   2016-11-01  company16777  job0029038      US            CO
# 8   2016-11-01  company36601  job0077381      US            FL
# 9   2016-11-01  company04480  job0005725      US            CT
# 10  2016-11-01  company30319  job0060501      US            CA
# 11  2016-11-01  company27756  job0054167      US            NV
# 12  2016-11-01  company11131  job0079771      US            KY
# 13  2016-11-01  company21969  job0040811      US            NJ
# 14  2016-11-01  company01073  job0034352      US            TN
# 15  2016-11-01  company24665  job0046807      US            GA
# 16  2016-11-01  company34118  job0070173      US            TX
# 17  2016-11-01  company21881  job0063303      US            NC
# 18  2016-11-01  company03627  job0073066      US            IL
# 19  2016-11-01  company07204  job0010364      US            NJ
# 20  2016-11-01  company33198  job0067859      US            MA
# 21  2016-11-01  company33199  job0067860      US            VA
# 22  2016-11-01  company36601  job0077383      US            NJ
# 23  2016-11-01  company24660  job0046797      US            GA
# 24  2016-11-01  company09503  job0016008      US            FL
# 25  2016-11-01  company21977  job0040829      US            CA
# 26  2016-11-01  company03292  job0054176      US            NE
# 27  2016-11-01  company00554  job0057316      US            KS
# 28  2016-11-01  company27862  job0063301      US            NY
# 29  2016-11-01  company07197  job0010352      US            TX
# ..         ...           ...         ...     ...           ...
# 70  2016-11-01  company24666  job0046808      US            CO
# 71  2016-11-01  company04477  job0005722      US            MI
# 72  2016-11-01  company11730  job0018551      US            CA
# 73  2016-11-01  company24668  job0046811      US            OH
# 74  2016-11-01  company35156  job0073067      US            AZ
# 75  2016-11-01  company10415  job0015997      US            WI
# 76  2016-11-01  company21968  job0040810      US            CT
# 77  2016-11-01  company13335  job0021713      US            VA
# 78  2016-11-01  company31532  job0063307      US            WA
# 79  2016-11-01  company02146  job0057322      US            TX
# 80  2016-11-01  company24669  job0046812      US            FL
# 81  2016-11-01  company35157  job0073069      US            FL
# 82  2016-11-01  company04832  job0079787      US            WI
# 83  2016-11-01  company04475  job0005720      US            NY
# 84  2016-11-01  company21966  job0040807      US            IN
# 85  2016-11-01  company27754  job0054159      US            CA
# 86  2016-11-01  company07518  job0054153      US            NC
# 87  2016-11-01  company03956  job0046813      US            CA
# 88  2016-11-01  company19163  job0034361      US            OH
# 89  2016-11-01  company01460  job0015994      US            VA
# 90  2016-11-01  company21979  job0040834      US            CA
# 91  2016-11-01  company33202  job0067866      US            WI
# 92  2016-11-01  company07522  job0073049      US            OK
# 93  2016-11-01  company29418  job0073051      US            CO
# 94  2016-11-01  company23518  job0070998      US            NY
# 95  2016-11-01  company21873  job0077398      US            NM
# 96  2016-11-01  company21873  job0077396      US            CA
# 97  2016-11-01  company12678  job0029053      US            CA
# 98  2016-11-01  company24656  job0046782      US       UNKNOWN
# 99  2016-11-01  company21991  job0040855      US            CA
#
#                               city  avgOverallRating  numReviews  \
# 0                           Peoria               0.0         NaN
# 1                      Gainesville               3.1      3576.0
# 2                           Dallas               4.0         9.0
# 3                          Yonkers               3.5        36.0
# 4   Charter Township of Brownstown               0.0         NaN
# 5                              NaN               3.4        67.0
# 6                        Charlotte               4.1        88.0
# 7                          Greeley               3.0        19.0
# 8                         Sarasota               0.0         NaN
# 9                         Hartford               3.4        70.0
# 10                   San Francisco               4.0        91.0
# 11                          Sparks               0.0         NaN
# 12                      Louisville               0.0         NaN
# 13                          Edison               0.0         NaN
# 14                       Knoxville               3.2        62.0
# 15                        Valdosta               4.7        18.0
# 16                      Seagoville               3.3        22.0
# 17                   Winston-Salem               0.0         NaN
# 18                         Chicago               3.9        62.0
# 19                        Vineland               0.0         NaN
# 20                       Cambridge               4.2       107.0
# 21                          Reston               0.0         NaN
# 22                     Jersey City               0.0         NaN
# 23                      Alpharetta               3.2       122.0
# 24                       Lake Mary               3.7      1257.0
# 25                     Los Angeles               0.0         NaN
# 26                         Norfolk               4.1       330.0
# 27                         Wichita               3.9        54.0
# 28                        Lagrange               0.0         NaN
# 29                          Irving               0.0         NaN
# ..                             ...               ...         ...
# 70                          Denver               3.2       792.0
# 71                           Flint               3.7        10.0
# 72               Pacific Palisades               0.0         NaN
# 73                      Miamisburg               5.0        49.0
# 74                  Fountain Hills               3.6        48.0
# 75                         Merrill               3.0        76.0
# 76                    Wethersfield               0.0         NaN
# 77                        Richmond               0.0         NaN
# 78                         Spokane               0.0         NaN
# 79                          Keller               0.0         NaN
# 80                   Daytona Beach               3.3         5.0
# 81                         Chipley               0.0         NaN
# 82                      New London               3.7        62.0
# 83                          Albany               2.5        52.0
# 84                    North Vernon               5.0        72.0
# 85                         Benicia               0.0         NaN
# 86                         Raleigh               4.2        35.0
# 87                        Palmdale               4.1        84.0
# 88                        Columbus               0.0         NaN
# 89                    Newport News               3.5        53.0
# 90                       San Diego               4.1       159.0
# 91                      New Berlin               3.1        20.0
# 92                           Tulsa               4.0       136.0
# 93                          Denver               3.7       129.0
# 94                      Huntington               3.6       151.0
# 95                           Raton               0.0         NaN
# 96                      West Hills               0.0         NaN
# 97                   Thousand Oaks               0.0         NaN
# 98                             NaN               4.1        77.0
# 99                   Beverly Hills               3.0        28.0
#
#                                              industry  \
# 0                                                 NaN
# 1                                         HEALTH_CARE
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                         HEALTH_CARE
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                 FOOD_AND_BEVERAGES
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                  AEROSPACE_AND_DEFENSE,HEALTH_CARE
# 21                              INTERNET_AND_SOFTWARE
# 22                                                NaN
# 23                                                NaN
# 24             BANKS_AND_FINANCIAL_SERVICES,INSURANCE
# 25                                                NaN
# 26                              INTERNET_AND_SOFTWARE
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 70  CONSULTING_AND_BUSINESS_SERVICES,HUMAN_RESOURC...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                     RESTAURANTS_TRAVEL_AND_LEISURE
# 75                                          INSURANCE
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                               ENERGY_AND_UTILITIES
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                 normTitle  ...   estimatedSalary  \
# 0         customer service representative  ...             22800
# 1                            case manager  ...             42600
# 2         licensed clinical social worker  ...             50300
# 3                                security  ...             41500
# 4                       grocery associate  ...             22600
# 5                   service technician ii  ...             34500
# 6                     claims investigator  ...             61000
# 7                                  welder  ...             32800
# 8                                     NaN  ...             38800
# 9                  director of compliance  ...            107500
# 10                      financial advisor  ...             66800
# 11                           bakery clerk  ...             40600
# 12                          administrator  ...             73400
# 13                  informatica developer  ...             97400
# 14                       district manager  ...             77800
# 15                        diesel mechanic  ...             33900
# 16                           dietary aide  ...             20700
# 17         member services representative  ...             15100
# 18           senior marketing coordinator  ...             62900
# 19            direct support professional  ...             19100
# 20                               security  ...             87300
# 21                                planner  ...             78900
# 22                                    NaN  ...             42300
# 23                       registered nurse  ...             46200
# 24                  claims representative  ...             37900
# 25                       office assistant  ...             30500
# 26                      field interviewer  ...             24300
# 27                sustainability engineer  ...             90200
# 28         member services representative  ...             13300
# 29                        legal secretary  ...             41000
# ..                                    ...  ...               ...
# 70                       security officer  ...             18900
# 71                          works manager  ...             53100
# 72                                  tutor  ...             46700
# 73                                laborer  ...             23700
# 74                        delivery driver  ...             25300
# 75                          summer intern  ...             56100
# 76                          cnc machinist  ...             33900
# 77              surveillance investigator  ...             38700
# 78                        fitness trainer  ...             37100
# 79                           food manager  ...             21800
# 80                       claims processor  ...             36300
# 81                              custodian  ...             20400
# 82                       machine operator  ...             22600
# 83                           food manager  ...             48400
# 84                  circulation assistant  ...             19800
# 85                           receptionist  ...             27000
# 86                    associate professor  ...             51000
# 87                               engineer  ...            101100
# 88              collection representative  ...             31600
# 89                            dog trainer  ...             24100
# 90                         senior counsel  ...             84000
# 91            inside sales representative  ...             48500
# 92             senior pharmacy technician  ...             34100
# 93       sales representative entry level  ...             61800
# 94                  residential counselor  ...             22400
# 95  registered nurse - medical / surgical  ...             76500
# 96  registered nurse - medical / surgical  ...             76800
# 97                                 editor  ...             73500
# 98              accounts receivable clerk  ...             24600
# 99                     surgical assistant  ...             83600
#
#     salaryCurrency  jobLanguage  supervisingJob  licenseRequiredJob  \
# 0              NaN           EN             0.0                 0.0
# 1              NaN           EN             1.0                 1.0
# 2              NaN           EN             0.0                 1.0
# 3              NaN           EN             1.0                 1.0
# 4              NaN           EN             0.0                 0.0
# 5              NaN           EN             1.0                 1.0
# 6              NaN           EN             0.0                 0.0
# 7              NaN           EN             0.0                 1.0
# 8              NaN           EN             0.0                 0.0
# 9              NaN           EN             1.0                 1.0
# 10             NaN           EN             0.0                 0.0
# 11             NaN           EN             0.0                 0.0
# 12             NaN           EN             0.0                 0.0
# 13             NaN           EN             0.0                 0.0
# 14             NaN           EN             1.0                 1.0
# 15             NaN           EN             0.0                 1.0
# 16             NaN           EN             0.0                 0.0
# 17             NaN           EN             0.0                 0.0
# 18             NaN           EN             0.0                 1.0
# 19             NaN           EN             0.0                 1.0
# 20             NaN           EN             0.0                 0.0
# 21             NaN           EN             0.0                 0.0
# 22             NaN           EN             0.0                 0.0
# 23             NaN           EN             0.0                 1.0
# 24             NaN           EN             0.0                 0.0
# 25             NaN           EN             0.0                 0.0
# 26             NaN           EN             0.0                 1.0
# 27             NaN           EN             0.0                 0.0
# 28             NaN           EN             0.0                 0.0
# 29             NaN           EN             0.0                 0.0
# ..             ...          ...             ...                 ...
# 70             NaN           EN             0.0                 0.0
# 71             NaN           EN             0.0                 0.0
# 72             NaN           EN             0.0                 0.0
# 73             USD           EN             0.0                 0.0
# 74             USD           EN             0.0                 1.0
# 75             NaN           EN             1.0                 0.0
# 76             NaN           EN             0.0                 0.0
# 77             USD           EN             0.0                 0.0
# 78             NaN           EN             0.0                 0.0
# 79             NaN           EN             1.0                 0.0
# 80             NaN           EN             0.0                 1.0
# 81             NaN           EN             0.0                 0.0
# 82             USD           EN             0.0                 0.0
# 83             NaN           EN             1.0                 0.0
# 84             NaN           EN             0.0                 0.0
# 85             NaN           EN             0.0                 0.0
# 86             NaN           EN             0.0                 1.0
# 87             NaN           EN             0.0                 0.0
# 88             USD           EN             0.0                 0.0
# 89             NaN           EN             0.0                 0.0
# 90             NaN           EN             0.0                 0.0
# 91             NaN           EN             0.0                 0.0
# 92             NaN           EN             0.0                 0.0
# 93             NaN           EN             0.0                 0.0
# 94             NaN           EN             0.0                 1.0
# 95             USD           EN             0.0                 1.0
# 96             USD           EN             0.0                 1.0
# 97             NaN           EN             1.0                 0.0
# 98             NaN           EN             0.0                 0.0
# 99             NaN           EN             0.0                 1.0
#
#    educationRequirements jobAgeDays  clicks  localClicks  label
# 0            High School         99      12            2      7
# 1       Higher Education         19      36           24   4323
# 2       Higher Education          5      88           14  46782
# 3       Higher Education         64      13            0  16876
# 4                   None         14      22            0  36406
# 5            High School         38      18            3  14295
# 6       Higher Education         10      11            1  42782
# 7       Higher Education         32      12            3  31774
# 8                   None          0      37           13  48431
# 9       Higher Education         75      12            1  15626
# 10      Higher Education         10      37            5  44274
# 11                  None         13       4            3  42577
# 12      Higher Education          0       7            4  25755
# 13                  None         21       6            1  38037
# 14      Higher Education         26      27            0   4701
# 15           High School         18       2            2  40344
# 16           High School          5      50            1  46783
# 17           High School          7      28            0  37974
# 18      Higher Education          4      42           17  13919
# 19           High School         64      23            1  20556
# 20      Higher Education          6      25            2  46285
# 21                  None          5      15            3  46286
# 22                  None          0      10            5  48432
# 23                  None         19      43            0  40341
# 24      Higher Education         52      34            1  23966
# 25                  None         22      21            9  38067
# 26                  None         14      35            6  13254
# 27      Higher Education         12      26            9   2738
# 28           High School          7      31            0  42689
# 29                  None         64      30            1  20536
# ..                   ...        ...     ...          ...    ...
# 70           High School         19      18            3  40345
# 71      Higher Education         76      32            5  15623
# 72      Higher Education         47       7            2  26456
# 73                  None         19      22            5  40349
# 74           High School          3      29            3  47337
# 75      Higher Education         52      27            1  24959
# 76           High School         22      37            0  38036
# 77      Higher Education         42      34            9  28312
# 78                  None          8       2            2  45127
# 79           High School         11      13            1   8495
# 80           High School         19      23            2  40352
# 81                  None          3      16            3  47338
# 82           High School          0      22            2  16164
# 83                  None         76       2            1  15621
# 84           High School         22      24            1  38035
# 85                  None         14      79            9  42576
# 86      Higher Education         14      56           21  21093
# 87      Higher Education         19      15            1  14482
# 88           High School         26       7            3  35276
# 89                  None         52      32            2   5653
# 90                  None         21       7            5  38068
# 91      Higher Education          6      22            0  46291
# 92                  None          3      11            2  21100
# 93      Higher Education          3      31           12  43672
# 94           High School          4      19           10  39387
# 95      Higher Education          0      24            3  37931
# 96      Higher Education          0      19            1  37930
# 97      Higher Education         31      40            5  27716
# 98           High School         18      31            0  40338
# 99                  None         22      19            3  38074
#
# [100 rows x 24 columns]

# %%
df.industry.unique()
# Out:
# array([nan, 'HEALTH_CARE', 'FOOD_AND_BEVERAGES',
#        'AEROSPACE_AND_DEFENSE,HEALTH_CARE', 'INTERNET_AND_SOFTWARE',
#        'BANKS_AND_FINANCIAL_SERVICES,INSURANCE',
#        'BANKS_AND_FINANCIAL_SERVICES', 'RETAIL',
#        'CONSUMER_GOODS_AND_SERVICES', 'EDUCATION_AND_SCHOOLS',
#        'TRANSPORT_AND_FREIGHT',
#        'CONSULTING_AND_BUSINESS_SERVICES,HUMAN_RESOURCES_AND_STAFFING',
#        'RESTAURANTS_TRAVEL_AND_LEISURE', 'INSURANCE',
#        'ENERGY_AND_UTILITIES', 'CONSTRUCTION',
#        'HEALTH_CARE,HUMAN_RESOURCES_AND_STAFFING',
#        'CONSULTING_AND_BUSINESS_SERVICES,HEALTH_CARE',
#        'AEROSPACE_AND_DEFENSE', 'COMPUTERS_AND_ELECTRONICS',
#        'HUMAN_RESOURCES_AND_STAFFING', 'CONSULTING_AND_BUSINESS_SERVICES',
#        'CONSTRUCTION,CONSUMER_GOODS_AND_SERVICES', 'GOVERNMENT', 'AUTO',
#        'INDUSTRIAL_MANUFACTURING',
#        'CONSULTING_AND_BUSINESS_SERVICES,INTERNET_AND_SOFTWARE',
#        'GOVERNMENT,HEALTH_CARE', 'REAL_ESTATE', 'TELECOMMUNICATIONS',
#        'BANKS_AND_FINANCIAL_SERVICES,REAL_ESTATE',
#        'AGRICULTURE_AND_EXTRACTION', 'ORGANIZATION',
#        'CONSUMER_GOODS_AND_SERVICES,FOOD_AND_BEVERAGES',
#        'CONSTRUCTION,INDUSTRIAL_MANUFACTURING',
#        'CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES,REAL_ESTATE',
#        'MEDIA_NEWS_AND_PUBLISHING',
#        'CONSUMER_GOODS_AND_SERVICES,INDUSTRIAL_MANUFACTURING',
#        'HEALTH_CARE,INDUSTRIAL_MANUFACTURING',
#        'AGRICULTURE_AND_EXTRACTION,CONSUMER_GOODS_AND_SERVICES',
#        'AEROSPACE_AND_DEFENSE,INDUSTRIAL_MANUFACTURING',
#        'BANKS_AND_FINANCIAL_SERVICES,HEALTH_CARE',
#        'AGRICULTURE_AND_EXTRACTION,RETAIL',
#        'FOOD_AND_BEVERAGES,INDUSTRIAL_MANUFACTURING',
#        'AUTO,BANKS_AND_FINANCIAL_SERVICES',
#        'CONSULTING_AND_BUSINESS_SERVICES,RETAIL',
#        'HEALTH_CARE,ORGANIZATION',
#        'CONSULTING_AND_BUSINESS_SERVICES,TRANSPORT_AND_FREIGHT',
#        'PHARMACEUTICALS',
#        'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING,TELECOMMUNICATIONS',
#        'CONSUMER_GOODS_AND_SERVICES,RETAIL',
#        'EDUCATION_AND_SCHOOLS,HEALTH_CARE',
#        'CONSULTING_AND_BUSINESS_SERVICES,GOVERNMENT',
#        'INDUSTRIAL_MANUFACTURING,INSURANCE',
#        'INDUSTRIAL_MANUFACTURING,TRANSPORT_AND_FREIGHT',
#        'ENERGY_AND_UTILITIES,INDUSTRIAL_MANUFACTURING',
#        'INSURANCE,MEDIA_NEWS_AND_PUBLISHING',
#        'BANKS_AND_FINANCIAL_SERVICES,CONSTRUCTION',
#        'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING',
#        'HEALTH_CARE,INSURANCE', 'COMPUTERS_AND_ELECTRONICS,RETAIL',
#        'INDUSTRIAL_MANUFACTURING,RETAIL',
#        'BANKS_AND_FINANCIAL_SERVICES,ENERGY_AND_UTILITIES',
#        'INDUSTRIAL_MANUFACTURING,TELECOMMUNICATIONS',
#        'AUTO,TRANSPORT_AND_FREIGHT', 'CONSTRUCTION,REAL_ESTATE',
#        'AUTO,RESTAURANTS_TRAVEL_AND_LEISURE',
#        'ENERGY_AND_UTILITIES,PHARMACEUTICALS',
#        'COMPUTERS_AND_ELECTRONICS,ENERGY_AND_UTILITIES',
#        'CONSTRUCTION,ENERGY_AND_UTILITIES',
#        'FOOD_AND_BEVERAGES,TRANSPORT_AND_FREIGHT',
#        'HUMAN_RESOURCES_AND_STAFFING,INTERNET_AND_SOFTWARE',
#        'CONSULTING_AND_BUSINESS_SERVICES,TELECOMMUNICATIONS',
#        'CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES',
#        'BANKS_AND_FINANCIAL_SERVICES,CONSULTING_AND_BUSINESS_SERVICES',
#        'AEROSPACE_AND_DEFENSE,HUMAN_RESOURCES_AND_STAFFING'], dtype=object)

# %%
dic = {'Agriculture':['AGRICULTURE_AND_EXTRACTION','AGRICULTURE_AND_EXTRACTION,CONSUMER_GOODS_AND_SERVICES'],
       'Construction':['CONSTRUCTION','REAL_ESTATE','CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES,REAL_ESTATE',
                       'CONSTRUCTION,REAL_ESTATE','CONSTRUCTION,ENERGY_AND_UTILITIES',
                       'CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES'],
       'Manufacturing':['FOOD_AND_BEVERAGES','RETAIL','CONSUMER_GOODS_AND_SERVICES','CONSTRUCTION,CONSUMER_GOODS_AND_SERVICES',
                        'AUTO','INDUSTRIAL_MANUFACTURING','CONSUMER_GOODS_AND_SERVICES,FOOD_AND_BEVERAGES',
                        'CONSTRUCTION,INDUSTRIAL_MANUFACTURING',
                       'CONSUMER_GOODS_AND_SERVICES,INDUSTRIAL_MANUFACTURING','PHARMACEUTICALS',
                        'CONSUMER_GOODS_AND_SERVICES,RETAIL',
                        'COMPUTERS_AND_ELECTRONICS,RETAIL','INDUSTRIAL_MANUFACTURING,RETAIL',
                        'INDUSTRIAL_MANUFACTURING,TELECOMMUNICATIONS'
                       ],
       'Transportation and Warehousing':['TRANSPORT_AND_FREIGHT','TRANSPORT_AND_FREIGHT',
                                         'CONSULTING_AND_BUSINESS_SERVICES,TRANSPORT_AND_FREIGHT',
                                         'INDUSTRIAL_MANUFACTURING,TRANSPORT_AND_FREIGHT','AUTO,TRANSPORT_AND_FREIGHT',
                                         'FOOD_AND_BEVERAGES,TRANSPORT_AND_FREIGHT'],
       'Utilities':['ENERGY_AND_UTILITIES','ENERGY_AND_UTILITIES,INDUSTRIAL_MANUFACTURING',
                    'ENERGY_AND_UTILITIES,PHARMACEUTICALS'],
       'Information':['INTERNET_AND_SOFTWARE','COMPUTERS_AND_ELECTRONICS','TELECOMMUNICATIONS',
                      'MEDIA_NEWS_AND_PUBLISHING','INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING,TELECOMMUNICATIONS',
                      'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING','COMPUTERS_AND_ELECTRONICS,ENERGY_AND_UTILITIES'],
       'Financial Activities':['BANKS_AND_FINANCIAL_SERVICES,INSURANCE','BANKS_AND_FINANCIAL_SERVICES','INSURANCE',
                               'BANKS_AND_FINANCIAL_SERVICES,REAL_ESTATE',
                               'AUTO,BANKS_AND_FINANCIAL_SERVICES','INDUSTRIAL_MANUFACTURING,INSURANCE',
                               'INSURANCE,MEDIA_NEWS_AND_PUBLISHING','HEALTH_CARE,INSURANCE',
                               'BANKS_AND_FINANCIAL_SERVICES,ENERGY_AND_UTILITIES','BANKS_AND_FINANCIAL_SERVICES,CONSTRUCTION',
                               'BANKS_AND_FINANCIAL_SERVICES,CONSULTING_AND_BUSINESS_SERVICES'  
                              ],
       'Business':['CONSULTING_AND_BUSINESS_SERVICES,HUMAN_RESOURCES_AND_STAFFING',
                   'HEALTH_CARE,HUMAN_RESOURCES_AND_STAFFING',
                  'CONSULTING_AND_BUSINESS_SERVICES,HEALTH_CARE','HUMAN_RESOURCES_AND_STAFFING',
                   'CONSULTING_AND_BUSINESS_SERVICES,INTERNET_AND_SOFTWARE',
                   'CONSULTING_AND_BUSINESS_SERVICES,RETAIL',
                   'HUMAN_RESOURCES_AND_STAFFING,INTERNET_AND_SOFTWARE',
                   'CONSULTING_AND_BUSINESS_SERVICES,TELECOMMUNICATIONS'
                  ],
       'Education':['EDUCATION_AND_SCHOOLS','CONSULTING_AND_BUSINESS_SERVICES','EDUCATION_AND_SCHOOLS,HEALTH_CARE'],       
       'Healthcare':['HEALTH_CARE','HEALTH_CARE,INDUSTRIAL_MANUFACTURING','HEALTH_CARE,ORGANIZATION'], 
       'Hospitality':['RESTAURANTS_TRAVEL_AND_LEISURE','AUTO,RESTAURANTS_TRAVEL_AND_LEISURE'],
       'Government':['AEROSPACE_AND_DEFENSE,HEALTH_CARE','AEROSPACE_AND_DEFENSE','GOVERNMENT','GOVERNMENT,HEALTH_CARE',
                     'AEROSPACE_AND_DEFENSE,INDUSTRIAL_MANUFACTURING',
                     'CONSULTING_AND_BUSINESS_SERVICES,GOVERNMENT','AEROSPACE_AND_DEFENSE,HUMAN_RESOURCES_AND_STAFFING'
                    ],
       'Other Services':['ORGANIZATION']
       
}

# %%
df['industrynew'] = df['industry']

# %%
df['industrynew'].nunique()
# Out:
# 75

# %%
df.loc[df['industrynew'] == 'Healthcare']
# Out:
#               date     companyId       jobId country stateProvince  \
# 1       2016-11-01  company00977  job0046801      US            FL
# 9       2016-11-01  company04480  job0005725      US            CT
# 200     2016-11-01  company02481  job0067836      US            WA
# 202     2016-11-01  company35168  job0077345      US            CA
# 203     2016-11-01  company35168  job0077348      US            CA
# 242     2016-11-01  company00671  job0028976      US            MD
# 247     2016-11-01  company14622  job0024442      US            WI
# 288     2016-11-01  company00225  job0034388      US            CA
# 301     2016-11-01  company13540  job0079796      US            NY
# 315     2016-11-01  company00225  job0005695      US            CA
# 344     2016-11-01  company21393  job0046828      US            CA
# 371     2016-11-01  company05029  job0054255      US            TX
# 379     2016-11-01  company05029  job0054254      US            TX
# 388     2016-11-01  company05751  job0024298      US            TX
# 399     2016-11-01  company15240  job0060564      US            KY
# 406     2016-11-01  company12779  job0029120      US            NY
# 429     2016-11-01  company14955  job0029114      US            TX
# 457     2016-11-01  company24566  job0046644      US            NY
# 475     2016-11-01  company01752  job0029146      US            TX
# 532     2016-11-01  company17509  job0054275      US            MI
# 541     2016-11-01  company08740  job0060570      US            OK
# 559     2016-11-01  company06166  job0067891      US            NJ
# 647     2016-11-01  company31507  job0063264      US            CA
# 660     2016-11-01  company00225  job0016037      US            GA
# 663     2016-11-01  company04549  job0005812      US            FL
# 735     2016-11-01  company05242  job0079862      US            WA
# 744     2016-11-01  company03081  job0073179      US            WA
# 775     2016-11-01  company15092  job0063498      US            PA
# 794     2016-11-01  company17045  job0060409      US            MD
# 811     2016-11-01  company33145  job0067745      US            VA
# ...            ...           ...         ...     ...           ...
# 787805  2016-11-30  company04340  job0131319      US            FL
# 787832  2016-11-30  company51580  job0126450      US            IN
# 787859  2016-11-30  company20230  job0122962      US            PA
# 787875  2016-11-30  company10769  job0016710      US            TN
# 787878  2016-11-30  company01101  job0020905      US            CA
# 787889  2016-11-30  company00225  job0088246      US            CA
# 787902  2016-11-30  company47182  job0111190      US            FL
# 787916  2016-11-30  company11361  job0017744      US            DC
# 787982  2016-11-30  company01599  job0017876      US            NC
# 788001  2016-11-30  company12735  job0102480      US            TN
# 788015  2016-11-30  company07772  job0120237      US            CA
# 788026  2016-11-30  company36347  job0132683      US            TX
# 788036  2016-11-30  company02728  job0037790      US            IL
# 788039  2016-11-30  company12178  job0034675      US            PA
# 788060  2016-11-30  company50851  job0123793      US            MO
# 788061  2016-11-30  company13829  job0119665      US            OH
# 788069  2016-11-30  company40659  job0120088      US            CA
# 788071  2016-11-30  company00914  job0036476      US            TX
# 788114  2016-11-30  company25090  job0140135      US            OH
# 788119  2016-11-30  company01251  job0130089      US            FL
# 788142  2016-11-30  company05691  job0089289      US            NM
# 788152  2016-11-30  company17172  job0124168      US            FL
# 788181  2016-11-30  company01123  job0112240      US            OH
# 788188  2016-11-30  company01539  job0083997      US            GA
# 788191  2016-11-30  company14472  job0111007      US            ME
# 788197  2016-11-30  company45808  job0106248      US            AZ
# 788229  2016-11-30  company24316  job0123589      US            CA
# 788262  2016-11-30  company29031  job0126127      US            WA
# 788277  2016-11-30  company13829  job0145490      US            OH
# 788432  2016-11-30  company16361  job0028154      US            MA
#
#                    city  avgOverallRating  numReviews     industry  \
# 1           Gainesville               3.1      3576.0  HEALTH_CARE
# 9              Hartford               3.4        70.0  HEALTH_CARE
# 200             Seattle               0.0         NaN  HEALTH_CARE
# 202          Sacramento               3.4       113.0  HEALTH_CARE
# 203     Fountain Valley               3.4       113.0  HEALTH_CARE
# 242         Catonsville               3.2       254.0  HEALTH_CARE
# 247           Milwaukee               3.5        87.0  HEALTH_CARE
# 288           San Diego               4.2      6716.0  HEALTH_CARE
# 301              Oswego               2.9        68.0  HEALTH_CARE
# 315             Fremont               4.2      6716.0  HEALTH_CARE
# 344            San Jose               4.1       175.0  HEALTH_CARE
# 371         San Antonio               3.9       175.0  HEALTH_CARE
# 379         San Antonio               3.9       175.0  HEALTH_CARE
# 388              Odessa               4.8        99.0  HEALTH_CARE
# 399           Lexington               0.0         NaN  HEALTH_CARE
# 406            Brooklyn               3.5       138.0  HEALTH_CARE
# 429          Round Rock               2.8        61.0  HEALTH_CARE
# 457             Chester               3.6        60.0  HEALTH_CARE
# 475            Pasadena               2.6        17.0  HEALTH_CARE
# 532             Portage               3.2       105.0  HEALTH_CARE
# 541       Oklahoma City               3.6       185.0  HEALTH_CARE
# 559              Camden               3.7       269.0  HEALTH_CARE
# 647             Lynwood               3.9       188.0  HEALTH_CARE
# 660              Duluth               4.2      6716.0  HEALTH_CARE
# 663            Sarasota               4.1       109.0  HEALTH_CARE
# 735             Seattle               0.0         NaN  HEALTH_CARE
# 744             Granger               3.5        59.0  HEALTH_CARE
# 775        Philadelphia               3.0        79.0  HEALTH_CARE
# 794           Rockville               4.2        63.0  HEALTH_CARE
# 811            Culpeper               3.6        97.0  HEALTH_CARE
# ...                 ...               ...         ...          ...
# 787805            Largo               3.0        23.0  HEALTH_CARE
# 787832       South Bend               4.0        48.0  HEALTH_CARE
# 787859           Topton               2.6       120.0  HEALTH_CARE
# 787875        Nashville               3.4       110.0  HEALTH_CARE
# 787878              NaN               3.7        42.0  HEALTH_CARE
# 787889        Santa Ana               4.2      6716.0  HEALTH_CARE
# 787902              NaN               0.0         NaN  HEALTH_CARE
# 787916       Washington               3.3        63.0  HEALTH_CARE
# 787982             King               3.7       596.0  HEALTH_CARE
# 788001       Germantown               4.2       202.0  HEALTH_CARE
# 788015         San Jose               4.8        97.0  HEALTH_CARE
# 788026           Austin               2.9       116.0  HEALTH_CARE
# 788036          Decatur               3.6        45.0  HEALTH_CARE
# 788039        Camp Hill               3.5       174.0  HEALTH_CARE
# 788060           Belton               0.0         NaN  HEALTH_CARE
# 788061       Cincinnati               3.8       127.0  HEALTH_CARE
# 788069    Monterey Park               3.3        75.0  HEALTH_CARE
# 788071           Dallas               4.0       156.0  HEALTH_CARE
# 788114           Canton               3.9       140.0  HEALTH_CARE
# 788119        Hollywood               4.2       478.0  HEALTH_CARE
# 788142         Santa Fe               0.0         NaN  HEALTH_CARE
# 788152         Aventura               0.0         NaN  HEALTH_CARE
# 788181         Columbus               4.1        74.0  HEALTH_CARE
# 788188              NaN               3.9        71.0  HEALTH_CARE
# 788191          Augusta               3.2        54.0  HEALTH_CARE
# 788197        Flagstaff               3.0        51.0  HEALTH_CARE
# 788229          Modesto               3.4        82.0  HEALTH_CARE
# 788262          Spokane               3.0       130.0  HEALTH_CARE
# 788277          Lebanon               3.8       127.0  HEALTH_CARE
# 788432           Boston               3.5       102.0  HEALTH_CARE
#
#                                      normTitle     ...     salaryCurrency  \
# 1                                 case manager     ...                NaN
# 9                       director of compliance     ...                NaN
# 200            patient services representative     ...                NaN
# 202     registered nurse - catheterization lab     ...                NaN
# 203                registered nurse - oncology     ...                NaN
# 242          internal communications executive     ...                NaN
# 247                          intake specialist     ...                NaN
# 288                        surgical technician     ...                NaN
# 301                           office assistant     ...                NaN
# 315                       psychology associate     ...                NaN
# 344                        registered nurse ii     ...                NaN
# 371                         dietary technician     ...                NaN
# 379                        billing coordinator     ...                NaN
# 388                         physical therapist     ...                NaN
# 399            customer service representative     ...                NaN
# 406                         nurse practitioner     ...                NaN
# 429                                  registrar     ...                NaN
# 457                   licensed practical nurse     ...                NaN
# 475                           registered nurse     ...                NaN
# 532              registered nurse case manager     ...                NaN
# 541                          nursing assistant     ...                NaN
# 559      senior information technology manager     ...                NaN
# 647                                 pharmacist     ...                NaN
# 660                           registered nurse     ...                NaN
# 663                   licensed practical nurse     ...                NaN
# 735          registered nurse - emergency room     ...                NaN
# 744                          medical assistant     ...                NaN
# 775                          nursing assistant     ...                NaN
# 794                               case manager     ...                USD
# 811                             utility worker     ...                NaN
# ...                                        ...     ...                ...
# 787805                  registered nurse - icu     ...                NaN
# 787832                             transporter     ...                NaN
# 787859                     activities director     ...                NaN
# 787875                        registered nurse     ...                NaN
# 787878               licensed vocational nurse     ...                NaN
# 787889               behavioral health manager     ...                NaN
# 787902                             orthopedist     ...                NaN
# 787916                mental health technician     ...                NaN
# 787982                     physician assistant     ...                NaN
# 788001             registered nurse - infusion     ...                NaN
# 788015             speech language pathologist     ...                NaN
# 788026                        registered nurse     ...                NaN
# 788036                    recreation therapist     ...                NaN
# 788039                       medical assistant     ...                NaN
# 788060                    medical technologist     ...                NaN
# 788061                      executive director     ...                NaN
# 788069                       field coordinator     ...                NaN
# 788071                    medical technologist     ...                NaN
# 788114                administrative assistant     ...                NaN
# 788119         patient services representative     ...                NaN
# 788142                      service technician     ...                NaN
# 788152                       resident director     ...                NaN
# 788181               quality assurance analyst     ...                NaN
# 788188                             orthopedist     ...                NaN
# 788191                        echocardiologist     ...                NaN
# 788197                            case manager     ...                USD
# 788229                     clinical technician     ...                NaN
# 788262                  occupational therapist     ...                NaN
# 788277                                 caterer     ...                NaN
# 788432              patient experience manager     ...                NaN
#
#         jobLanguage  supervisingJob  licenseRequiredJob  \
# 1                EN             1.0                 1.0
# 9                EN             1.0                 1.0
# 200              EN             0.0                 1.0
# 202              EN             0.0                 1.0
# 203              EN             0.0                 1.0
# 242              EN             1.0                 0.0
# 247              EN             0.0                 1.0
# 288              EN             0.0                 1.0
# 301              EN             0.0                 0.0
# 315              EN             0.0                 1.0
# 344              EN             0.0                 1.0
# 371              EN             0.0                 0.0
# 379              EN             1.0                 0.0
# 388              EN             0.0                 1.0
# 399              EN             0.0                 1.0
# 406              EN             0.0                 1.0
# 429              EN             0.0                 0.0
# 457              EN             0.0                 1.0
# 475              EN             0.0                 1.0
# 532              EN             0.0                 1.0
# 541              EN             0.0                 1.0
# 559              EN             1.0                 1.0
# 647              EN             0.0                 1.0
# 660              EN             0.0                 1.0
# 663              EN             0.0                 1.0
# 735              EN             0.0                 1.0
# 744              EN             0.0                 1.0
# 775              EN             0.0                 1.0
# 794              EN             1.0                 0.0
# 811              EN             0.0                 0.0
# ...             ...             ...                 ...
# 787805           EN             0.0                 1.0
# 787832           EN             0.0                 1.0
# 787859           EN             0.0                 1.0
# 787875           EN             1.0                 1.0
# 787878           EN             0.0                 1.0
# 787889           EN             1.0                 1.0
# 787902           EN             0.0                 0.0
# 787916           EN             0.0                 0.0
# 787982           EN             0.0                 1.0
# 788001           EN             0.0                 1.0
# 788015           EN             0.0                 1.0
# 788026           EN             0.0                 1.0
# 788036           EN             0.0                 1.0
# 788039           EN             0.0                 1.0
# 788060           EN             0.0                 1.0
# 788061           EN             1.0                 0.0
# 788069           EN             0.0                 0.0
# 788071           EN             0.0                 1.0
# 788114           EN             1.0                 1.0
# 788119           EN             0.0                 1.0
# 788142           EN             0.0                 1.0
# 788152           EN             1.0                 1.0
# 788181           EN             1.0                 0.0
# 788188           EN             0.0                 0.0
# 788191           EN             0.0                 1.0
# 788197           EN             0.0                 1.0
# 788229           EN             0.0                 1.0
# 788262           EN             0.0                 1.0
# 788277           EN             0.0                 0.0
# 788432           EN             1.0                 0.0
#
#         educationRequirements jobAgeDays clicks  localClicks  label  \
# 1            Higher Education         19     36           24   4323
# 9            Higher Education         75     12            1  15626
# 200          Higher Education          6     13            2  11204
# 202                      None          0     20            0  47356
# 203                      None          0     12            0  47357
# 242          Higher Education         32     25            0   3115
# 247          Higher Education         38     22           13  29614
# 288                      None         27     18            3   1097
# 301               High School          0     78           23  28541
# 315                      None         76     10            0   1082
# 344                      None         19     27            3  37502
# 371               High School         14     31           16  16498
# 379          Higher Education         14     24            0  16497
# 388                      None         38     13           13  17970
# 399               High School         10     19            5  30350
# 406          Higher Education         31      7            7  27801
# 429                      None         31     18            3  29993
# 457                      None         19     20            3  40275
# 475                      None         31     29            0   6845
# 532                      None         13     27            1  32871
# 541               High School         10     19           19  22817
# 559          Higher Education          6     35            3  18803
# 647                      None          7     29            2  45117
# 660          Higher Education         52     21            2   1088
# 663                      None         76      9            3  15676
# 735                      None          0     10            5  16896
# 744               High School          4     37            2  12836
# 775               High School          7     36           26  30119
# 794                      None         10     14            1  32036
# 811               High School          6     30            7  46258
# ...                       ...        ...    ...          ...    ...
# 787805                   None          7     26            1  15260
# 787832            High School          9     69           23  55352
# 787859            High School         12     19            2  36301
# 787875                   None         79     25            6  25334
# 787878                   None         72     15            0   4830
# 787889       Higher Education         26     10            0   1120
# 787902       Higher Education         15     20            0  53570
# 787916            High School         77      8            0  26003
# 787982       Higher Education         77     26            0   6118
# 788001                   None         20     23            0  27782
# 788015       Higher Education         13     16            9  21406
# 788026       Higher Education          7     28           15  48264
# 788036                   None         54     36            1  12114
# 788039                   None         55      9            0  27050
# 788060       Higher Education         11     20            0  55080
# 788061                   None         13     10            0  28838
# 788069            High School         13     14            0  50618
# 788071       Higher Education         54     29           12   4129
# 788114       Higher Education          2    370           70  40707
# 788119            High School          8      8            0   5173
# 788142                   None         26      8            0  17908
# 788152                   None         11     13            0  32324
# 788181       Higher Education         15     43            9   4896
# 788188                   None         27     26            0   5942
# 788191       Higher Education         16     10            1  29449
# 788197                   None         19     23            4  52956
# 788229            High School         11      6            0  40030
# 788262                   None          9     25           18  43437
# 788277            High School          0     35            0  28840
# 788432       Higher Education         61     40            7  31348
#
#        industrynew
# 1       Healthcare
# 9       Healthcare
# 200     Healthcare
# 202     Healthcare
# 203     Healthcare
# 242     Healthcare
# 247     Healthcare
# 288     Healthcare
# 301     Healthcare
# 315     Healthcare
# 344     Healthcare
# 371     Healthcare
# 379     Healthcare
# 388     Healthcare
# 399     Healthcare
# 406     Healthcare
# 429     Healthcare
# 457     Healthcare
# 475     Healthcare
# 532     Healthcare
# 541     Healthcare
# 559     Healthcare
# 647     Healthcare
# 660     Healthcare
# 663     Healthcare
# 735     Healthcare
# 744     Healthcare
# 775     Healthcare
# 794     Healthcare
# 811     Healthcare
# ...            ...
# 787805  Healthcare
# 787832  Healthcare
# 787859  Healthcare
# 787875  Healthcare
# 787878  Healthcare
# 787889  Healthcare
# 787902  Healthcare
# 787916  Healthcare
# 787982  Healthcare
# 788001  Healthcare
# 788015  Healthcare
# 788026  Healthcare
# 788036  Healthcare
# 788039  Healthcare
# 788060  Healthcare
# 788061  Healthcare
# 788069  Healthcare
# 788071  Healthcare
# 788114  Healthcare
# 788119  Healthcare
# 788142  Healthcare
# 788152  Healthcare
# 788181  Healthcare
# 788188  Healthcare
# 788191  Healthcare
# 788197  Healthcare
# 788229  Healthcare
# 788262  Healthcare
# 788277  Healthcare
# 788432  Healthcare
#
# [31436 rows x 25 columns]

# %%
df['industrynew'].nunique()
# Out:
# 73

# %%
df['industrynew'].replace(['HEALTH_CARE','HEALTH_CARE,INDUSTRIAL_MANUFACTURING',
                           'HEALTH_CARE,ORGANIZATION','BANKS_AND_FINANCIAL_SERVICES,HEALTH_CARE'], 
                          'Healthcare',inplace=True)
df['industrynew'].replace(['ORGANIZATION'], 'Other Services',inplace = True)
df['industrynew'].replace(['AEROSPACE_AND_DEFENSE,HEALTH_CARE',
                                            'AEROSPACE_AND_DEFENSE','GOVERNMENT',
                                            'GOVERNMENT,HEALTH_CARE',
                                             'AEROSPACE_AND_DEFENSE,INDUSTRIAL_MANUFACTURING',
                                             'CONSULTING_AND_BUSINESS_SERVICES,GOVERNMENT',
                                            'AEROSPACE_AND_DEFENSE,HUMAN_RESOURCES_AND_STAFFING'
                                            ], 'Government',inplace = True)
df['industrynew'].replace(['RESTAURANTS_TRAVEL_AND_LEISURE',
                                            'AUTO,RESTAURANTS_TRAVEL_AND_LEISURE'],
                                           'Hospitality',inplace = True)
df['industrynew'].replace(['EDUCATION_AND_SCHOOLS','CONSULTING_AND_BUSINESS_SERVICES',
                                            'EDUCATION_AND_SCHOOLS,HEALTH_CARE'], 
                                           'Education',inplace = True)
df['industrynew'].replace(['CONSULTING_AND_BUSINESS_SERVICES,HUMAN_RESOURCES_AND_STAFFING',
                   'HEALTH_CARE,HUMAN_RESOURCES_AND_STAFFING',
                  'CONSULTING_AND_BUSINESS_SERVICES,HEALTH_CARE',
                 'HUMAN_RESOURCES_AND_STAFFING',
                   'CONSULTING_AND_BUSINESS_SERVICES,INTERNET_AND_SOFTWARE',
                   'CONSULTING_AND_BUSINESS_SERVICES,RETAIL',
                   'HUMAN_RESOURCES_AND_STAFFING,INTERNET_AND_SOFTWARE',
                   'CONSULTING_AND_BUSINESS_SERVICES,TELECOMMUNICATIONS'
                  ], 'Business',inplace = True)
df['industrynew'].replace(['BANKS_AND_FINANCIAL_SERVICES,INSURANCE',
                                            'BANKS_AND_FINANCIAL_SERVICES','INSURANCE',
                               'BANKS_AND_FINANCIAL_SERVICES,REAL_ESTATE',
                               'AUTO,BANKS_AND_FINANCIAL_SERVICES','INDUSTRIAL_MANUFACTURING,INSURANCE',
                               'INSURANCE,MEDIA_NEWS_AND_PUBLISHING','HEALTH_CARE,INSURANCE',
                               'BANKS_AND_FINANCIAL_SERVICES,ENERGY_AND_UTILITIES',
                                 'BANKS_AND_FINANCIAL_SERVICES,CONSTRUCTION',
                               'BANKS_AND_FINANCIAL_SERVICES,CONSULTING_AND_BUSINESS_SERVICES'  
                              ], 'Financial Activities',inplace = True)
df['industrynew'].replace(['INTERNET_AND_SOFTWARE','COMPUTERS_AND_ELECTRONICS',
                                            'TELECOMMUNICATIONS',
                                              'MEDIA_NEWS_AND_PUBLISHING',
                                            'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING,TELECOMMUNICATIONS',
                                              'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING',
                                            'COMPUTERS_AND_ELECTRONICS,ENERGY_AND_UTILITIES'], 
                                           'Information',inplace = True)
df['industrynew'].replace(['TRANSPORT_AND_FREIGHT','TRANSPORT_AND_FREIGHT',
                                         'CONSULTING_AND_BUSINESS_SERVICES,TRANSPORT_AND_FREIGHT',
                                         'INDUSTRIAL_MANUFACTURING,TRANSPORT_AND_FREIGHT',
                                            'AUTO,TRANSPORT_AND_FREIGHT',
                                         'FOOD_AND_BEVERAGES,TRANSPORT_AND_FREIGHT'], 
                                           'Transportation and Warehousing',inplace = True)
df['industrynew'].replace(['FOOD_AND_BEVERAGES','RETAIL','CONSUMER_GOODS_AND_SERVICES','CONSTRUCTION,CONSUMER_GOODS_AND_SERVICES',
                        'AUTO','INDUSTRIAL_MANUFACTURING','CONSUMER_GOODS_AND_SERVICES,FOOD_AND_BEVERAGES',
                        'CONSTRUCTION,INDUSTRIAL_MANUFACTURING',
                       'CONSUMER_GOODS_AND_SERVICES,INDUSTRIAL_MANUFACTURING','PHARMACEUTICALS',
                        'CONSUMER_GOODS_AND_SERVICES,RETAIL',
                        'COMPUTERS_AND_ELECTRONICS,RETAIL','INDUSTRIAL_MANUFACTURING,RETAIL',
                        'INDUSTRIAL_MANUFACTURING,TELECOMMUNICATIONS','FOOD_AND_BEVERAGES,INDUSTRIAL_MANUFACTURING','AGRICULTURE_AND_EXTRACTION,RETAIL',
                       ], 'Manufacturing_and_Retail',inplace = True)
df['industrynew'].replace(['CONSTRUCTION','REAL_ESTATE','CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES,REAL_ESTATE',
                       'CONSTRUCTION,REAL_ESTATE','CONSTRUCTION,ENERGY_AND_UTILITIES',
                       'CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES'], 'Construction',inplace = True)
df['industrynew'].replace(['ENERGY_AND_UTILITIES','ENERGY_AND_UTILITIES,INDUSTRIAL_MANUFACTURING',
                    'ENERGY_AND_UTILITIES,PHARMACEUTICALS'], 'Utilities',inplace = True)

df['industrynew'].replace(['AGRICULTURE_AND_EXTRACTION','AGRICULTURE_AND_EXTRACTION,CONSUMER_GOODS_AND_SERVICES'], 'Agriculture',inplace = True)

# %%
df['industrynew'].nunique()
# Out:
# 14

# %%
df.head()
# Out:
#          date     companyId       jobId country stateProvince  \
# 0  2016-11-01  company00002  job0000002      US            AZ
# 1  2016-11-01  company00977  job0046801      US            FL
# 2  2016-11-01  company34117  job0070172      US            TX
# 3  2016-11-01  company05230  job0010362      US            NY
# 4  2016-11-01  company20349  job0054168      US            MI
#
#                              city  avgOverallRating  numReviews     industry  \
# 0                          Peoria               0.0         NaN          NaN
# 1                     Gainesville               3.1      3576.0  HEALTH_CARE
# 2                          Dallas               4.0         9.0          NaN
# 3                         Yonkers               3.5        36.0          NaN
# 4  Charter Township of Brownstown               0.0         NaN          NaN
#
#                          normTitle     ...     salaryCurrency  jobLanguage  \
# 0  customer service representative     ...                NaN           EN
# 1                     case manager     ...                NaN           EN
# 2  licensed clinical social worker     ...                NaN           EN
# 3                         security     ...                NaN           EN
# 4                grocery associate     ...                NaN           EN
#
#    supervisingJob  licenseRequiredJob  educationRequirements jobAgeDays  \
# 0             0.0                 0.0            High School         99
# 1             1.0                 1.0       Higher Education         19
# 2             0.0                 1.0       Higher Education          5
# 3             1.0                 1.0       Higher Education         64
# 4             0.0                 0.0                   None         14
#
#   clicks  localClicks  label industrynew
# 0     12            2      7         NaN
# 1     36           24   4323  Healthcare
# 2     88           14  46782         NaN
# 3     13            0  16876         NaN
# 4     22            0  36406         NaN
#
# [5 rows x 25 columns]

# %%
df.industrynew.unique()
# Out:
# array([nan, 'HEALTH_CARE', 'FOOD_AND_BEVERAGES',
#        'AEROSPACE_AND_DEFENSE,HEALTH_CARE', 'INTERNET_AND_SOFTWARE',
#        'BANKS_AND_FINANCIAL_SERVICES,INSURANCE',
#        'BANKS_AND_FINANCIAL_SERVICES', 'RETAIL',
#        'CONSUMER_GOODS_AND_SERVICES', 'EDUCATION_AND_SCHOOLS',
#        'TRANSPORT_AND_FREIGHT',
#        'CONSULTING_AND_BUSINESS_SERVICES,HUMAN_RESOURCES_AND_STAFFING',
#        'RESTAURANTS_TRAVEL_AND_LEISURE', 'INSURANCE',
#        'ENERGY_AND_UTILITIES', 'CONSTRUCTION',
#        'HEALTH_CARE,HUMAN_RESOURCES_AND_STAFFING',
#        'CONSULTING_AND_BUSINESS_SERVICES,HEALTH_CARE',
#        'AEROSPACE_AND_DEFENSE', 'COMPUTERS_AND_ELECTRONICS',
#        'HUMAN_RESOURCES_AND_STAFFING', 'CONSULTING_AND_BUSINESS_SERVICES',
#        'CONSTRUCTION,CONSUMER_GOODS_AND_SERVICES', 'GOVERNMENT', 'AUTO',
#        'INDUSTRIAL_MANUFACTURING',
#        'CONSULTING_AND_BUSINESS_SERVICES,INTERNET_AND_SOFTWARE',
#        'GOVERNMENT,HEALTH_CARE', 'REAL_ESTATE', 'TELECOMMUNICATIONS',
#        'BANKS_AND_FINANCIAL_SERVICES,REAL_ESTATE',
#        'AGRICULTURE_AND_EXTRACTION', 'Other Services',
#        'CONSUMER_GOODS_AND_SERVICES,FOOD_AND_BEVERAGES',
#        'CONSTRUCTION,INDUSTRIAL_MANUFACTURING',
#        'CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES,REAL_ESTATE',
#        'MEDIA_NEWS_AND_PUBLISHING',
#        'CONSUMER_GOODS_AND_SERVICES,INDUSTRIAL_MANUFACTURING',
#        'HEALTH_CARE,INDUSTRIAL_MANUFACTURING',
#        'AGRICULTURE_AND_EXTRACTION,CONSUMER_GOODS_AND_SERVICES',
#        'AEROSPACE_AND_DEFENSE,INDUSTRIAL_MANUFACTURING',
#        'BANKS_AND_FINANCIAL_SERVICES,HEALTH_CARE',
#        'AGRICULTURE_AND_EXTRACTION,RETAIL',
#        'FOOD_AND_BEVERAGES,INDUSTRIAL_MANUFACTURING',
#        'AUTO,BANKS_AND_FINANCIAL_SERVICES',
#        'CONSULTING_AND_BUSINESS_SERVICES,RETAIL',
#        'HEALTH_CARE,ORGANIZATION',
#        'CONSULTING_AND_BUSINESS_SERVICES,TRANSPORT_AND_FREIGHT',
#        'PHARMACEUTICALS',
#        'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING,TELECOMMUNICATIONS',
#        'CONSUMER_GOODS_AND_SERVICES,RETAIL',
#        'EDUCATION_AND_SCHOOLS,HEALTH_CARE',
#        'CONSULTING_AND_BUSINESS_SERVICES,GOVERNMENT',
#        'INDUSTRIAL_MANUFACTURING,INSURANCE',
#        'INDUSTRIAL_MANUFACTURING,TRANSPORT_AND_FREIGHT',
#        'ENERGY_AND_UTILITIES,INDUSTRIAL_MANUFACTURING',
#        'INSURANCE,MEDIA_NEWS_AND_PUBLISHING',
#        'BANKS_AND_FINANCIAL_SERVICES,CONSTRUCTION',
#        'INTERNET_AND_SOFTWARE,MEDIA_NEWS_AND_PUBLISHING',
#        'HEALTH_CARE,INSURANCE', 'COMPUTERS_AND_ELECTRONICS,RETAIL',
#        'INDUSTRIAL_MANUFACTURING,RETAIL',
#        'BANKS_AND_FINANCIAL_SERVICES,ENERGY_AND_UTILITIES',
#        'INDUSTRIAL_MANUFACTURING,TELECOMMUNICATIONS',
#        'AUTO,TRANSPORT_AND_FREIGHT', 'CONSTRUCTION,REAL_ESTATE',
#        'AUTO,RESTAURANTS_TRAVEL_AND_LEISURE',
#        'ENERGY_AND_UTILITIES,PHARMACEUTICALS',
#        'COMPUTERS_AND_ELECTRONICS,ENERGY_AND_UTILITIES',
#        'CONSTRUCTION,ENERGY_AND_UTILITIES',
#        'FOOD_AND_BEVERAGES,TRANSPORT_AND_FREIGHT',
#        'HUMAN_RESOURCES_AND_STAFFING,INTERNET_AND_SOFTWARE',
#        'CONSULTING_AND_BUSINESS_SERVICES,TELECOMMUNICATIONS',
#        'CONSTRUCTION,CONSULTING_AND_BUSINESS_SERVICES',
#        'BANKS_AND_FINANCIAL_SERVICES,CONSULTING_AND_BUSINESS_SERVICES',
#        'AEROSPACE_AND_DEFENSE,HUMAN_RESOURCES_AND_STAFFING'], dtype=object)

# %%
df.groupby('stateProvince')['industry'].nunique().sort_values()
# Out:
# stateProvince
# VI          0
# PR          0
# GU          0
# MT          7
# VT          7
# RI          8
# NH          8
# ID          8
# AK          8
# WY          8
# HI          9
# SD         11
# ND         12
# DE         13
# DC         14
# WV         14
# ME         14
# AR         15
# NE         15
# MS         15
# IA         15
# NM         16
# UNKNOWN    16
# CT         16
# OK         17
# NV         17
# LA         17
# OR         19
# KS         20
# KY         20
# SC         20
# UT         20
# WI         21
# MO         22
# MI         22
# NJ         23
# GA         24
# AL         24
# TN         25
# IN         26
# MN         26
# MD         26
# WA         26
# MA         27
# VA         28
# CO         28
# NC         28
# IL         28
# AZ         29
# FL         29
# NY         31
# OH         33
# PA         35
# CA         40
# TX         40
# Name: industry, dtype: int64

# %%
df.industry.isnull().sum()
# Out:
# 689492

# %%
df.shape
# Out:
# (788435, 24)

# %%
df.groupby('stateProvince')['companyId'].nunique().sort_values()
# Out:
# stateProvince
# VI            3
# GU            3
# PR           25
# WY           64
# AK           80
# VT          101
# SD          104
# ND          111
# MT          122
# RI          133
# ID          149
# HI          158
# DE          162
# WV          183
# ME          187
# MS          204
# NM          222
# NH          240
# UNKNOWN     256
# AR          259
# NE          268
# NV          320
# DC          356
# OK          386
# KS          389
# UT          391
# IA          392
# LA          394
# AL          429
# OR          465
# KY          495
# CT          531
# SC          570
# MO          721
# WI          764
# TN          784
# IN          809
# MN          865
# MD          876
# AZ          878
# CO          898
# WA          921
# NC         1109
# NJ         1126
# MI         1149
# MA         1162
# GA         1168
# VA         1215
# OH         1395
# PA         1589
# IL         1616
# FL         2125
# NY         2181
# TX         2730
# CA         4017
# Name: companyId, dtype: int64

# %%
df[df.industry == 'FOOD_AND_BEVERAGES,INDUSTRIAL_MANUFACTURING']['normTitle']
# Out:
# 5548      human resources generalist
# 5552            maintenance mechanic
# 8916         supply chain specialist
# 27744        supply chain specialist
# 37443           maintenance mechanic
# 37465     human resources generalist
# 42524     human resources generalist
# 42560           maintenance mechanic
# 54856        supply chain specialist
# 77712     human resources generalist
# 77741           maintenance mechanic
# 80188        supply chain specialist
# 92172        supply chain specialist
# 96877     human resources generalist
# 96880           maintenance mechanic
# 119929    human resources generalist
# 119983          maintenance mechanic
# 123226       supply chain specialist
# 143722       supply chain specialist
# 147052          maintenance mechanic
# 147055    human resources generalist
# 148525     senior maintenance person
# 178466     senior maintenance person
# 184387       supply chain specialist
# 186250          maintenance mechanic
# 186410    human resources generalist
# 187870    human resources generalist
# 188102          maintenance mechanic
# 197334     senior maintenance person
# 198345       supply chain specialist
#                      ...
# 628571          maintenance mechanic
# 629224    human resources generalist
# 639514       supply chain specialist
# 639881                credit analyst
# 651091     senior maintenance person
# 656955                credit analyst
# 659243     senior maintenance person
# 672910    human resources generalist
# 673020          maintenance mechanic
# 680633       supply chain specialist
# 687692       supply chain specialist
# 690615                credit analyst
# 699102          maintenance mechanic
# 699165    human resources generalist
# 707611     senior maintenance person
# 714892     senior maintenance person
# 720266                credit analyst
# 726355       supply chain specialist
# 732031    human resources generalist
# 732032          maintenance mechanic
# 735746          maintenance mechanic
# 735750    human resources generalist
# 752548     senior maintenance person
# 757430                credit analyst
# 760248       supply chain specialist
# 765711          maintenance mechanic
# 765751    human resources generalist
# 769438                credit analyst
# 778197     senior maintenance person
# 786595       supply chain specialist
# Name: normTitle, Length: 134, dtype: object
