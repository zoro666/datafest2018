# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
read = "/home/zoro/Desktop/datafest2018/DataFest-Dataset-2018.csv/data2/"

# %%
df = pd.read_csv(read+'US.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0        date     companyId       jobId country stateProvince  \
# 0           1  2016-11-01  company00002  job0000002      US            AZ
# 1      527676  2016-11-01  company00977  job0046801      US            FL
# 2      886221  2016-11-01  company34117  job0070172      US            TX
# 3       60352  2016-11-01  company05230  job0010362      US            NY
# 4      632550  2016-11-01  company20349  job0054168      US            MI
# 5      249059  2016-11-01  company03785  job0024376      US            IA
# 6      733638  2016-11-01  company27976  job0060502      US            NC
# 7      325567  2016-11-01  company16777  job0029038      US            CO
# 8      996957  2016-11-01  company36601  job0077381      US            FL
# 9       22785  2016-11-01  company04480  job0005725      US            CT
#
#                              city  avgOverallRating  numReviews     industry  \
# ...

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'date', u'companyId', u'jobId', u'country',
#        u'stateProvince', u'city', u'avgOverallRating', u'numReviews',
#        u'industry', u'normTitle', u'normTitleCategory',
#        u'descriptionCharacterLength', u'descriptionWordCount',
#        u'experienceRequired', u'estimatedSalary', u'salaryCurrency',
#        u'jobLanguage', u'supervisingJob', u'licenseRequiredJob',
#        u'educationRequirements', u'jobAgeDays', u'clicks', u'localClicks'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head(10)
# Out:
#          date     companyId       jobId country stateProvince  \
# 0  2016-11-01  company00002  job0000002      US            AZ
# 1  2016-11-01  company00977  job0046801      US            FL
# 2  2016-11-01  company34117  job0070172      US            TX
# 3  2016-11-01  company05230  job0010362      US            NY
# 4  2016-11-01  company20349  job0054168      US            MI
# 5  2016-11-01  company03785  job0024376      US            IA
# 6  2016-11-01  company27976  job0060502      US            NC
# 7  2016-11-01  company16777  job0029038      US            CO
# 8  2016-11-01  company36601  job0077381      US            FL
# 9  2016-11-01  company04480  job0005725      US            CT
#
#                              city  avgOverallRating  numReviews     industry  \
# 0                          Peoria               0.0         NaN          NaN
# 1                     Gainesville               3.1      3576.0  HEALTH_CARE
# ...

# %%
df.tail(5)
# Out:
#                 date      companyId       jobId country stateProvince  \
# 11547899  2017-11-30  company219535  job0907578      US            TX
# 11547900  2017-11-30  company219548  job0907626      US            NY
# 11547901  2017-11-30   company90718  job1016666      US            NJ
# 11547902  2017-11-30   company49131  job0908145      US            MO
# 11547903  2017-11-30  company221821  job1041309      US            CA
#
#                             city  avgOverallRating  numReviews industry  \
# 11547899             San Antonio               0.0         NaN      NaN
# 11547900                Syracuse               0.0         NaN      NaN
# 11547901           Atlantic City               0.0         NaN      NaN
# 11547902               St. Louis               3.9        36.0      NaN
# 11547903  Rancho Santa Margarita               0.0         NaN      NaN
#
#                     normTitle     ...     experienceRequired  estimatedSalary  \
# ...

# %%
df.isnull().sum()
# Out:
# date                                 0
# companyId                            0
# jobId                                0
# country                              0
# stateProvince                        0
# city                            262251
# avgOverallRating                     0
# numReviews                     5871151
# industry                      10163336
# normTitle                       745883
# normTitleCategory               745883
# descriptionCharacterLength           0
# descriptionWordCount                 0
# experienceRequired             6864142
# estimatedSalary                      0
# salaryCurrency                 9685028
# jobLanguage                          0
# supervisingJob                    2456
# licenseRequiredJob                2456
# educationRequirements             2456
# jobAgeDays                           0
# clicks                               0
# localClicks                          0
# dtype: int64

# %%
df.stateProvince.value_counts()
# Out:
# CA         1336804
# TX          906323
# FL          688840
# NY          677474
# IL          490156
# PA          485702
# OH          432732
# VA          371434
# NC          371351
# GA          362067
# MA          361156
# MI          351947
# NJ          331959
# WA          276351
# MD          254430
# CO          250222
# IN          241748
# MN          241648
# AZ          233334
# WI          232167
# MO          220468
# TN          218926
# SC          169470
# CT          136055
# OR          133938
# KY          132061
# AL          131017
# OK          110698
# LA          109982
# IA          106665
# UT          105968
# KS          103162
# NV           91062
# DC           79730
# AR           77935
# UNKNOWN      70919
# NE           64486
# NH           64134
# MS           58658
# NM           53768
# WV           49145
# ME           47441
# ID           46272
# RI           40060
# HI           38688
# DE           35740
# ND           29576
# ...

# %%
df1 = df

# %%
df['label'] = df.groupby(['companyId', 'jobId']).ngroup()

# %%
df.label.nunique()
# Out:
# 413800

# %%
df.head(5)
# Out:
#          date     companyId       jobId country stateProvince  \
# 0  2016-11-01  company00002  job0000002      US            AZ
# 1  2016-11-01  company00977  job0046801      US            FL
# 2  2016-11-01  company34117  job0070172      US            TX
# 3  2016-11-01  company05230  job0010362      US            NY
# 4  2016-11-01  company20349  job0054168      US            MI
#
#                              city  avgOverallRating  numReviews     industry  \
# 0                          Peoria               0.0         NaN          NaN
# 1                     Gainesville               3.1      3576.0  HEALTH_CARE
# 2                          Dallas               4.0         9.0          NaN
# 3                         Yonkers               3.5        36.0          NaN
# 4  Charter Township of Brownstown               0.0         NaN          NaN
#
#                          normTitle   ...   estimatedSalary  salaryCurrency  \
# ...

# %%
write = '/home/zoro/Desktop/datafest2018/DataFest-Dataset-2018.csv/data2/'

# %%
df.to_csv(write+'US_clean1.csv')
